# %%
from ultralytics import YOLO

# %%
model: YOLO = YOLO(
    model='../models/cpu/yolov8s-seg.pt',
    task='segment',    
)

# %%
model.info()
# Out:
# YOLOv8s-seg summary: 261 layers, 11,821,056 parameters, 0 gradients, 42.9 GFLOPs
# (261, 11821056, 0, 42.860595200000006)

# %%
model.train(
    data='../data.yaml',
    epochs=1000,
    imgsz=640
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.23 🚀 Python-3.12.0 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11912MiB)
# ...
